# %%
import os
# Find the latest version of spark 3.0 from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.3'
spark_version = 'spark-3.0.3'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
#!apt-get update
#!apt-get install openjdk-11-jdk-headless -qq > /dev/null
#!wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
#!tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
#!pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession

# %%
import pandas as pd

# %% [markdown]
# READ TSV FILE AND WRITE TO CSV FILE

# %%
# Python program to convert .tsv file to .csv file
# importing re library
import re
  
# reading given tsv file
with open("/Users/mimir/Desktop/county_market_tracker.tsv000", 'r') as myfile:  
  with open("county_market_tracker.csv", 'w') as csv_file:
    for line in myfile:
        
      # Replace every tab with comma
      fileContent = re.sub("\t", ",", line)
        
      # Writing into csv file
      csv_file.write(fileContent)
  
# output
print("Successfully made csv file")
# Out:
# Successfully made csv file

# %% [markdown]
# CREATE DATAFRAME FROM CSV FILE

# %%
county_market_tracker_df = pd.read_csv("county_market_tracker.csv")
county_market_tracker_df.head()
# Out:
#                        period_begin period_end  period_duration  region_type  \
# 2020-07-01 2020-07-31            30     county                5         3101
# 2021-05-01 2021-05-31            30     county                5         3182
# 2015-02-01 2015-02-28            30     county                5         1870
# 2019-04-01 2019-04-30            30     county                5         2327
# 2020-11-01 2020-11-30            30     county                5         2168
#
#                       region_type_id            table_id  \
# 2020-07-01 2020-07-31              f      Stevens County
# 2021-05-01 2021-05-31              f  Fond du Lac County
# 2015-02-01 2015-02-28              f     Humboldt County
# 2019-04-01 2019-04-30              f    Clackamas County
# 2020-11-01 2020-11-30              f       Butler County
#
#                       is_seasonally_adjusted  region        city state  ...  \
# 2020-07-01 2020-07-31                     WA     NaN  Washington    WA  ...
# ...

# %% [markdown]
# CREATE A DATAFRAME FOR DAVIDSON COUNTY AND THE STATE OF TN

# %%
davidson_county_df = county_market_tracker_df
# davidson_county_df[county_market_tracker_df['table_id']=='Davidson County']
davidson_county_df[(county_market_tracker_df['table_id']=='Davidson County') & (county_market_tracker_df['state']=='TN')]
# Out:
#                        period_begin period_end  period_duration  region_type  \
# 2020-05-01 2020-05-31            30     county                5         2563
# 2020-04-01 2020-04-30            30     county                5         2563
# 2021-10-01 2021-10-31            30     county                5         2563
# 2021-08-01 2021-08-31            30     county                5         2563
# 2018-02-01 2018-02-28            30     county                5         2563
# ...                             ...        ...              ...          ...
# 2019-02-01 2019-02-28            30     county                5         2563
# 2019-06-01 2019-06-30            30     county                5         2563
# 2013-10-01 2013-10-31            30     county                5         2563
# 2015-07-01 2015-07-31            30     county                5         2563
# 2022-02-01 2022-02-28            30     county                5         2563
#
# ...

# %%
nashville_df = davidson_county_df[(county_market_tracker_df['table_id']=='Davidson County') & (county_market_tracker_df['state']=='TN')]
nashville_df
# Out:
#                        period_begin period_end  period_duration  region_type  \
# 2020-05-01 2020-05-31            30     county                5         2563
# 2020-04-01 2020-04-30            30     county                5         2563
# 2021-10-01 2021-10-31            30     county                5         2563
# 2021-08-01 2021-08-31            30     county                5         2563
# 2018-02-01 2018-02-28            30     county                5         2563
# ...                             ...        ...              ...          ...
# 2019-02-01 2019-02-28            30     county                5         2563
# 2019-06-01 2019-06-30            30     county                5         2563
# 2013-10-01 2013-10-31            30     county                5         2563
# 2015-07-01 2015-07-31            30     county                5         2563
# 2022-02-01 2022-02-28            30     county                5         2563
#
# ...

# %%
# SAVE CSV FILE
nashville_df.to_csv('davidson_county.csv')

# %% [markdown]
# CREATE A DATAFRAME FROM ORIGINAL DF TO INCLUDE ALL COUNTIES IN TN

# %%
tn_counties_df = county_market_tracker_df
tn_counties_df[county_market_tracker_df['state']=='TN']
# Out:
#                        period_begin period_end  period_duration  region_type  \
# 2020-06-01 2020-06-30            30     county                5         2623
# 2021-09-01 2021-09-30            30     county                5         2557
# 2014-10-01 2014-10-31            30     county                5         2608
# 2022-02-01 2022-02-28            30     county                5         2549
# 2013-08-01 2013-08-31            30     county                5         2572
# ...                             ...        ...              ...          ...
# 2020-12-01 2020-12-31            30     county                5         2616
# 2014-06-01 2014-06-30            30     county                5         2593
# 2021-04-01 2021-04-30            30     county                5         2627
# 2021-10-01 2021-10-31            30     county                5         2627
# 2019-05-01 2019-05-31            30     county                5         2632
#
# ...

# %%
# SAVE CSV FILE
tn_counties_df.to_csv('tn_county.csv')
